# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("D3 (1).csv")
df.head(100)

m = df.X1.size
X = df.values[:,0]
y = df.Y
#Set zeros array for theta
theta = np.zeros(2)
iterations = 1500;
alpha = 0.01;
#Defining the compute cost and gradient descent functions from lectures
def computeCost(X,y,theta):
  """
  Compute cost for linear regression.
  Input Parameters
  ----------------
  X : 2D array where each row represent the training example and each column represent
  m= number of training examples
  n= number of features (including X_0 column of ones)
  y : 1D array of labels/target value for each traing example. dimension(1 x m)
  theta : 1D array of fitting parameters or weights. Dimension (1 x n)
  Output Parameters
  -----------------
  J : Scalar value.
  """
  m = len(X)
  predictions = X.dot(theta)
  errors = np.subtract(predictions, y)
  sqrErrors = np.square(errors)
  J = 1 / (2 * m) * np.sum(sqrErrors)
  return J

def gradientDescent(X, y, theta, alpha, iterations):
  """
  Compute cost for linear regression.

  Input Parameters
  ----------------
  X : 2D array where each row represent the training example and each column represent
      m= number of training examples
      n= number of features (including X_0 column of ones)
  y : 1D array of labels/target value for each traing example. dimension(m x 1)
  theta : 1D array of fitting parameters or weights. Dimension ( n x 1)
  alpha : Learning rate. Scalar value
  iterations: No of iterations. Scalar value.

  Output Parameters
  -----------------
  theta : Final Value. 1D array of fitting parameters or weights. Dimension (1 x n)
  cost_history: Conatins value of cost for each iteration. 1D array. Dimansion(m x 1)  """
  cost_history = np.zeros(iterations)

  for i in range(iterations):
    predictions = X.dot(theta)
    errors = np.subtract(predictions, y)
    sum_delta = (alpha / m) * X.transpose().dot(errors);
    theta = theta - sum_delta;
    cost_history[i] = computeCost(X, y, theta)
  return theta, cost_history
X = df.values[:, 0] # X1 column
y = df.values[:, 3] # Y column
m = len(y) # training examples
#Plot data points given in scatter plot
plt.scatter(X,y, color='red',marker= 'X')
plt.grid()

plt.xlabel('X1')
plt.ylabel('Y')
plt.title('Training data Scatter Plot')

# matrix with single column of ones
X_0 = np.ones((m, 1))
# convert X 1D array to 2D array
X_1 = X.reshape(m, 1)
# stack X_0 and X_1 horizontally
# final X matrix
X = np.hstack((X_0, X_1))

# Cost for theta
cost = computeCost(X, y, theta)
print('The cost for given values of theta_0 and theta_1 =', cost)
theta = [0., 0.]
iterations = 1500;
alpha = 0.01;
#Gradient Descent used to find final values of theta
theta, cost_history = gradientDescent(X, y, theta, alpha, iterations)
print('Final value of theta =', theta)
print('cost_history =', cost_history)

#Linear Regression Line
plt.scatter(X[:,1], y, color='red', marker= '+', label= 'Training Data')
plt.plot(X[:,1],X.dot(theta), color='green', label='Linear Regression')
plt.grid()
plt.xlabel('X1')
plt.ylabel('Y')
plt.title('Linear Regression Fit')
plt.legend()
# Out:
# The cost for given values of theta_0 and theta_1 = 5.524438459196242
# Final value of theta = [ 5.71850653 -1.9568206 ]
# cost_history = [5.48226715 5.44290965 5.40604087 ... 0.99063932 0.99061433 0.99058944]

# %%
# Convergence of Gradient Descent plot shows iterations vs cost. Steeper curve/ Too shallow of a curve is not a good learning rate need to be an even balance between iterations and cost per iteration
plt.plot(range(1, iterations + 1),cost_history, color='green')
plt.grid()
plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')
# Out:
# Text(0.5, 1.0, 'Convergence of gradient descent')

# %%
#Regression for X2 values
X = df.values[:, 1] # X2 column
y = df.values[:, 3] # Y column
m = len(y) # training exmaples
#Scatter plot for X2 data vs Y
plt.scatter(X,y, color='red',marker= 'X')
plt.grid()

plt.xlabel('X2')
plt.ylabel('Y')
plt.title('Training Data Scatter Plot')

#Matrix for single column of Ones
X_0 = np.ones((m, 1))

# Convert to 2D Array
X_1 = X.reshape(m, 1)
# Stacking horizontally
# Final X matrix
X = np.hstack((X_0, X_1))
theta = np.zeros(2)
# Cost for theta values
cost = computeCost(X, y, theta)
print('The cost for given values of theta_0 and theta_1 =', cost)
iterations = 1500;
alpha = 0.001; #Set as 0.001 to test and find the best fit for cost vs iterations
#To find final value of theta...
theta, cost_history = gradientDescent(X, y, theta, alpha, iterations)
print('Final value of theta =', theta)
print('cost_history =', cost_history)
# Plot scatter plot and linear reg fit for X2...
plt.scatter(X[:,1], y, color='red', marker= 'X', label= 'Training Data')
plt.plot(X[:,1],X.dot(theta), color='green', label='Linear Regression')
plt.grid()
plt.xlabel('X2')
plt.ylabel('Y')
plt.title('Linear Regression Fit')
plt.legend()
# Out:
# The cost for given values of theta_0 and theta_1 = 5.524438459196242
# Final value of theta = [0.41275557 0.68335862]
# cost_history = [5.50118218 5.47821041 5.45551967 ... 3.61271034 3.61270443 3.61269852]

# %%
#Gradient Descent.... Steep or Too shallow is not optimal use of system. Look for something in between and use learning rate to adust... 0.001 Seems to be the best fit for the information of X2
plt.plot(range(1, iterations + 1),cost_history, color='green')
plt.grid()
plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')
# Out:
# Text(0.5, 1.0, 'Convergence of gradient descent')

# %%
#Regression for X3
X = df.values[:, 2] # X3 Column
y = df.values[:, 3] # Y column
m = len(y) # Training Examples total

#Scatter Plot of X3 VS Y
plt.scatter(X,y, color='red',marker= 'X')
plt.grid()
plt.xlabel('X3')
plt.ylabel('Y')
plt.title('Training Data Scatter Plot')

#Matrix of ones in a single column for reshaping
X_0 = np.ones((m, 1))
# Reshape to 2d
X_1 = X.reshape(m, 1)
# stacking
# final matrix for the X3 Values
X = np.hstack((X_0, X_1))

theta = np.zeros(2)

# Theta values costs
cost = computeCost(X, y, theta)
print('The cost for given values of theta_0 and theta_1 =', cost)
iterations = 1500;#1500 iterations seems to fit the plot well and prove a proper linear reg line
alpha = 0.01;#0.01 was used here as it provided the best fit for both the linear regression as well as the cost vs iterations
#Final theta value and cost history
theta, cost_history = gradientDescent(X, y, theta, alpha, iterations)
print('Final value of theta =', theta)
print('cost_history =', cost_history)
#Plot scatter and linear regression line of X3
plt.scatter(X[:,1], y, color='red', marker= 'X', label= 'Training Data')
plt.plot(X[:,1],X.dot(theta), color='green', label='Linear Regression')
plt.grid()
plt.xlabel('X3')
plt.ylabel('Y')
plt.title('Linear Regression Fit')
plt.legend()
# Out:
# The cost for given values of theta_0 and theta_1 = 5.524438459196242
# Final value of theta = [ 2.78048129 -0.48451631]
# cost_history = [5.40768785 5.30397076 5.21178297 ... 3.63053597 3.6305311  3.63052625]

# %%
#Gradient Descent plot of cost vs iterations... 0.01 was used here as it provided the best fit based on the graph below of gradient descent
plt.plot(range(1, iterations + 1),cost_history, color='green')
plt.grid()
plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')
# Out:
# Text(0.5, 1.0, 'Convergence of gradient descent')

# %%
X_3 = df.values[:, 0:3] # all X values X1,X2,X3
print(X.shape)
y = df.values[:, 3] # Y VALUES
m = len(y) # Training data total
#Plot of all data points together scatter plit
plt.scatter(X_3[:,0],y, color='red',marker= 'X')
plt.scatter(X_3[:,1],y, color='green',marker= '+')
plt.scatter(X_3[:,2],y, color='blue',marker= '.')
plt.grid()
plt.xlabel('X1')
plt.ylabel('Y')
plt.title('Scatter plot of training data')
#Column of ones
X_0 = np.ones((m, 1))
#Stacking
X = np.hstack((X_0, X_3))
theta = np.zeros(4)
iterations = 1500;
alpha = 0.01;
# Computing cost for values of theta
cost = computeCost(X, y, theta)
print('The cost for given values of theta_0, theta_1, theta_2 and theta_3 =', cost)
#Cost History
theta, cost_history = gradientDescent(X, y, theta, alpha, iterations)
print('Final value of theta =', theta)
print('cost_history =', cost_history)

# Scatter plot with linear regression fit so show optimal iterations and learning rate
plt.scatter(X[:,1], y, color='red', marker= 'X', label= 'Training Data')
plt.plot(X[:,1],X.dot(theta), color='red', label='Linear Regression')
plt.grid()
plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear Regression Fit')
# Out:
# (100, 2)
# The cost for given values of theta_0, theta_1, theta_2 and theta_3 = 5.524438459196242
# Final value of theta = [ 4.15118728 -1.8394291   0.72473856 -0.09513266]
# cost_history = [5.21542243 4.97171977 4.7765543  ... 0.81079843 0.81065429 0.81051044]
# Text(0.5, 1.0, 'Linear Regression Fit')

# %%
#Gradient Descent plot which shows whether the learning rate and iteration values were optimal... 0.01 was used as the learning rate which provided the best fit for the linear reg and gradient descent
plt.plot(range(1, iterations + 1),cost_history, color='green')
plt.rcParams["figure.figsize"] = (10,6)
plt.grid()
plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')

#Predict the value of y for new (X1, X2, X3) values (1, 1, 1), for (2, 0, 4), and for (3, 2, 1)
#Est a new array for the new X values and calculating the New Y based on the system
new_arr = np.array([[1, 1, 1],
                    [2, 0, 4],
                    [3, 2, 1]])

new_arr_0 = np.ones((len(new_arr), 1))
new_arr_x = np.hstack((new_arr_0, new_arr))
new_y = new_arr_x.dot(theta)
print('New Y = ', new_y)
# Out:
# New Y =  [ 2.94136408  0.09179843 -0.01275555]
